# %% [markdown]
# # Pymaceuticals Inc.
# ---
#
# ### Analysis
#
# The following analysis includes 10 total drug treatments for the entire study. Findings from the study indicated the highest performing drug treatments included Capomulin and Ramicane. These two drug treatments were signicantly more successful with reducing the tumor size more than the other drugs present in the study.
#
# A more-focused analysis was done on the Drug Regimen "Capomulin" on Mouse ID "I509." Findings indicated that this drug regimen was successful in shrinking the tumor volume over time (days).
#
# The final two graphs show a strong correlation (0.84) between mouse weight and average tumor volume variables. As the mouse weight increases, the average tumor volume increases too. This could potentially mean a mouse may need a higher dose of a drug in order to see the same successful results.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single DataFrame
data_and_results_df = pd.merge(study_results,mouse_metadata, on="Mouse ID", how="left")

# Display the data table for preview
data_and_results_df.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0     b128          0                45.0                 0    Capomulin
# 1     f932          0                45.0                 0     Ketapril
# 2     g107          0                45.0                 0     Ketapril
# 3     a457          0                45.0                 0     Ketapril
# 4     c819          0                45.0                 0     Ketapril
#
#       Sex  Age_months  Weight (g)
# 0  Female           9          22
# 1    Male          15          29
# 2  Female           2          29
# 3  Female          11          30
# 4    Male          21          25

# %%
# Checking the number of mice.
mice_count = mouse_metadata["Mouse ID"].count()
mice_count
# Out:
# 249

# %%
# Our data should be uniquely identified by Mouse ID and Timepoint
# Get the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
sorted_by_mice = data_and_results_df.loc[data_and_results_df.duplicated(["Mouse ID", "Timepoint"]),"Mouse ID"].unique()
sorted_by_mice
# Out:
# array(['g989'], dtype=object)

# %%
# Optional: Get all the data for the duplicate mouse ID. 
only_g989 = data_and_results_df.loc[data_and_results_df["Mouse ID"] == "g989"]
only_g989
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 107      g989          0           45.000000                 0     Propriva
# 137      g989          0           45.000000                 0     Propriva
# 329      g989          5           48.786801                 0     Propriva
# 360      g989          5           47.570392                 0     Propriva
# 620      g989         10           51.745156                 0     Propriva
# 681      g989         10           49.880528                 0     Propriva
# 815      g989         15           51.325852                 1     Propriva
# 869      g989         15           53.442020                 0     Propriva
# 950      g989         20           55.326122                 1     Propriva
# 1111     g989         20           54.657650                 1     Propriva
# 1195     g989         25           56.045564                 1     Propriva
# ...

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
# Slack Learning Assistant helped come to this conclusion
no_more_duplicate_mouse = data_and_results_df[data_and_results_df['Mouse ID'].isin(sorted_by_mice)==False]

#no_more_duplicate_mouse = data_and_results_df.drop_duplicates(["Mouse ID"])
no_more_duplicate_mouse.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0     b128          0                45.0                 0    Capomulin
# 1     f932          0                45.0                 0     Ketapril
# 2     g107          0                45.0                 0     Ketapril
# 3     a457          0                45.0                 0     Ketapril
# 4     c819          0                45.0                 0     Ketapril
#
#       Sex  Age_months  Weight (g)
# 0  Female           9          22
# 1    Male          15          29
# 2  Female           2          29
# 3  Female          11          30
# 4    Male          21          25

# %%
# Checking the number of mice in the clean DataFrame.
new_mice_count = len(no_more_duplicate_mouse["Mouse ID"].unique())
new_mice_count
# Out:
# 248

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen
# Use of Stack Overflow to help figure out I needed to use "numberic_only" to be successful 
means = data_and_results_df.groupby("Drug Regimen").mean(numeric_only=True)["Tumor Volume (mm3)"]
medians = data_and_results_df.groupby("Drug Regimen").median(numeric_only=True)["Tumor Volume (mm3)"]
variances = data_and_results_df.groupby("Drug Regimen").var(numeric_only=True)["Tumor Volume (mm3)"]
standard_deviations = data_and_results_df.groupby("Drug Regimen").std(numeric_only=True)["Tumor Volume (mm3)"]
SEMs = data_and_results_df.groupby("Drug Regimen").sem(numeric_only=True)["Tumor Volume (mm3)"]

# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume. 

# Assemble the resulting series into a single summary DataFrame.

stats_summary = pd.DataFrame({
                "Mean Tumor Volume":means,
                "Median Tumor Volume":medians,
                "Tumor Volume Variance":variances,
                "Tumor Volume Std. Dev.":standard_deviations,
                "Tumor Volume Std. Err.":SEMs})
stats_summary
# Out:
#               Mean Tumor Volume  Median Tumor Volume  Tumor Volume Variance  \
# Drug Regimen
# Capomulin             40.675741            41.557809              24.947764
# Ceftamin              52.591172            51.776157              39.290177
# Infubinol             52.884795            51.820584              43.128684
# Ketapril              55.235638            53.698743              68.553577
# Naftisol              54.331565            52.509285              66.173479
# Placebo               54.033581            52.288934              61.168083
# Propriva              52.322552            50.854632              42.351070
# Ramicane              40.216745            40.673236              23.486704
# Stelasyn              54.233149            52.431737              59.450562
# Zoniferol             53.236507            51.818479              48.533355
#
#               Tumor Volume Std. Dev.  Tumor Volume Std. Err.
# Drug Regimen
# ...

# %%
# A more advanced method to generate a summary statistics table of mean, median, variance, standard deviation,
# and SEM of the tumor volume for each regimen (only one method is required in the solution)

# Using the aggregation method, produce the same summary statistics in a single line
grouped_by_drug = data_and_results_df.groupby("Drug Regimen")
summary = grouped_by_drug["Tumor Volume (mm3)"].agg(['mean','median','var','std','sem'])
summary
# Out:
#                    mean     median        var       std       sem
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo       54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva      52.322552  50.854632  42.351070  6.507770  0.512884
# Ramicane      40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn      54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol     53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
sorted_drug_count = data_and_results_df.groupby(["Drug Regimen"])["Timepoint"].count().sort_values(ascending=False)
sorted_drug_count
# Out:
# Drug Regimen
# Capomulin    230
# Ramicane     228
# Ketapril     188
# Naftisol     186
# Zoniferol    182
# Placebo      181
# Stelasyn     181
# Ceftamin     178
# Infubinol    178
# Propriva     161
# Name: Timepoint, dtype: int64

# %%
# Generate a bar plot showing the total number of rows (Mouse ID/Timepoints) for each drug regimen using Pandas.
sorted_drug_count = data_and_results_df.groupby(["Drug Regimen"])["Timepoint"].count().sort_values(ascending=False)
sorted_drug_count

sorted_drug_count.plot(kind="bar",xlabel="Drug Regimen", ylabel="# of Observed Mouse Timepoints")
plt.show()

# %%
# Generate a bar plot showing the total number of rows (Mouse ID/Timepoints) for each drug regimen using pyplot.
sorted_drug_count = data_and_results_df.groupby("Drug Regimen")["Timepoint"].count()
sorted_drug_count

drugs = sorted_drug_count.index
drug_count = sorted_drug_count.values

plt.bar(drugs, drug_count)

# Labeling the axes
plt.xlabel("Drug Regimen")
plt.ylabel("# of Observed Mouse Timepoints")

plt.xticks(rotation=90)

plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using Pandas
gender_sort = no_more_duplicate_mouse.groupby("Sex")["Sex"].count()
gender_plot = gender_sort.plot(kind="pie", y="Sex", autopct='%1.1f%%', figsize=(6,6))
gender_plot
# Out:
# <Axes: ylabel='Sex'>

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
gender_sort = no_more_duplicate_mouse.groupby("Sex")["Sex"].count()
gender_sort

labels = ["Female","Male"]
colors = ["orange","blue"]
plt.pie(gender_sort, labels=labels, colors=colors, shadow=True,autopct='%1.1f%%')
plt.axis("equal")
plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin

# Start by getting the last (greatest) timepoint for each mouse
by_mouse = no_more_duplicate_mouse.groupby(["Mouse ID"]).max()
by_mouse_reset = by_mouse.reset_index()

# Merge this group df with the original DataFrame to get the tumor volume at the last timepoint
merge_df = by_mouse_reset[["Mouse ID","Timepoint"]].\
    merge(no_more_duplicate_mouse,on=["Mouse ID", "Timepoint"],how="left")

# %%
# Put treatments into a list for for loop (and later for plot labels)
drugs = ['Capomulin', 'Ramicane', 'Infubinol', 'Ceftamin']
# Create empty list to fill with tumor vol data (for plotting)
final_voltumor_list = []

for drug in drugs:
    
    # Locate the rows which contain mice on each drug and get the tumor volumes
    final_tumor_volume = merge_df.loc[merge_df["Drug Regimen"] == drug]['Tumor Volume (mm3)']
    
    # add subset to final_voltumor_list
    final_voltumor_list.append(final_tumor_volume)
    
    # Calculate the IQR and quantitatively determine if there are any potential outliers.
    quartiles = final_tumor_volume.quantile([.25,.5,.75])
    quart_first = quartiles[0.25]
    quart_last = quartiles[0.75]
    iqr = quart_last - quart_first
    lower_bound = quart_first - (1.5 * iqr)
    upper_bound = quart_last + (1.5 * iqr)
    mean = final_tumor_volume.mean()

    # Determine outliers using upper and lower bounds
    outliers = final_tumor_volume.loc[(final_tumor_volume < lower_bound) 
                  | (final_tumor_volume > upper_bound)]
    
    # Print results for each drug regimen 
    print(f"{drug} Regimen")
    print(f"The lower quartile of {drug} treatments is {round(lower_bound,2)}. Below this number are outliers. ")
    print(f"The upper quartile of {drug} treatments are {round(upper_bound,2)}. Above this number are outliers.")
    print(f"The average tumor volume(mm3) for {drug} is: {round(mean,2)}")
    print(f"Number of outliers for Capomulin is: {outliers.count()}")
    print("**************************")
# Out:
# Capomulin Regimen
# The lower quartile of Capomulin treatments is 20.7. Below this number are outliers.
# The upper quartile of Capomulin treatments are 51.83. Above this number are outliers.
# The average tumor volume(mm3) for Capomulin is: 36.67
# Number of outliers for Capomulin is: 0
# **************************
# Ramicane Regimen
# The lower quartile of Ramicane treatments is 17.91. Below this number are outliers.
# The upper quartile of Ramicane treatments are 54.31. Above this number are outliers.
# The average tumor volume(mm3) for Ramicane is: 36.19
# Number of outliers for Capomulin is: 0
# **************************
# Infubinol Regimen
# The lower quartile of Infubinol treatments is 36.83. Below this number are outliers.
# The upper quartile of Infubinol treatments are 82.74. Above this number are outliers.
# The average tumor volume(mm3) for Infubinol is: 58.18
# Number of outliers for Capomulin is: 1
# **************************
# Ceftamin Regimen
# ...

# %%
# Generate a box plot that shows the distribution of the tumor volume for each treatment group.
fig, ax = plt.subplots()  # Get the Figure and Axes objects

# Use the Axes object (ax) to create the box plot
ax.boxplot(final_voltumor_list, labels=drugs, flierprops={'markerfacecolor': 'r', 'markersize': 10})

# Set x/y label, title
ax.set_title('Final Tumor Volume \n(Four Treatment Regimens)', fontweight='bold')
ax.set_xlabel('Drug Regimen', fontweight='bold')
ax.set_ylabel('Final Tumor Volume (mm3)', fontweight='bold')

# Present the box plot chart
plt.show()

# To close pyplot (optional)
plt.close()

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a single mouse treated with Capomulin
# Generate dataframe only in Capomulin Regimen
Capomulin_df = no_more_duplicate_mouse.loc[no_more_duplicate_mouse['Drug Regimen'] == 'Capomulin']

# Identify specific mouse ID and get data of the mouse id
mouse_id = 'l509'
mouse_df = Capomulin_df.loc[Capomulin_df['Mouse ID'] == mouse_id]

# Generate a line plot
time_vol = plt.plot(mouse_df['Timepoint'], mouse_df['Tumor Volume (mm3)'], color='b')

# Set x/y label, title
plt.title(f"Capomulin Treatment of Mouse ID {mouse_id}", fontweight='bold')
plt.xlabel('Timepoint (days)', fontweight='bold')
plt.ylabel('Tumor Volume (mm3)', fontweight='bold')

# Present the box plot chart
plt.show()

# To close pyplot
plt.close()

# %%
# Generate a scatter plot of mouse weight vs. the average observed tumor volume for the entire Capomulin regimen

# Calculate mean of Weight (g) and Tumor Volume (mm3) based on Mouse ID
Capomulin_gp = Capomulin_df.groupby('Mouse ID')
mice_weight_avg = Capomulin_gp['Weight (g)'].mean()
mice_tumor_avg = Capomulin_gp['Tumor Volume (mm3)'].mean()

# Generate a scatter plot
plt.scatter(mice_weight_avg, mice_tumor_avg, marker="o", facecolors="blue", edgecolors="black", s = mice_weight_avg, alpha=0.75)

# Set x/y label, title
plt.title('Weight vs Average Tumor Volume \n(Capomulin regimen)', fontweight='bold')
plt.xlabel('Weight (g)', fontweight='bold')
plt.ylabel('Average Tumor Volume (mm3)', fontweight='bold')

# Present the box plot chart
plt.show()

# To close pyplot
plt.close()

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and a linear regression model 
# for mouse weight and average observed tumor volume for the entire Capomulin regimen

# Define x,y values
x_values = mice_weight_avg
y_values = mice_tumor_avg

# Calculate the correlation
correlation = round(st.pearsonr(x_values, y_values)[0],2)
print(f"The correlation between mouse weight and tumor vol is {correlation}")

# Calculate linear regression values
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)

# Calculate r-squared
r_squared = round(rvalue**2,2)
print(f"The r-squared is: {r_squared}")

# y = mx + b
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Gernerate scatter chart with liner regression line, equation of line, r-squared value
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values, color='r', alpha=0.7)

# Plot the Annotation in the graph 
plt.annotate(line_eq,(20,37), fontsize=11, color="red")
plt.annotate(f'r-squared = {r_squared}', (20,36), fontsize=11, color="red")

# Define title and x/y labels
plt.title('Weight vs Average Tumor Volume \n(Capomulin regimen)', fontweight='bold')
plt.xlabel('Weight (g)', fontweight='bold')
plt.ylabel('Average Tumor Volume (mm3)', fontweight='bold')

# Present the box plot chart
plt.show()

# To close pyplot
plt.close()
# Out:
# The correlation between mouse weight and tumor vol is 0.84
# The r-squared is: 0.71
